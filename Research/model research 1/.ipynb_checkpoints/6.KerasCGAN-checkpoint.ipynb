# %%
# %pwd
# Out:
# 'D:\\Desktop\\Deep Learning\\GAN for Face expression Classification\\Research'

# %%
import os

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'D:\\Desktop\\Deep Learning\\GAN for Face expression Classification'

# %%
import logging
from pathlib import Path
logging.basicConfig(
    # filename='extract_data.log',
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
)

# %%
import os
import shutil
from pathlib import Path
from PIL import Image
import logging


class CopyAndAugmentBalancedDataset:
    def __init__(self, source_directory, copy_directory, target_size=(256, 256)):
        self.source_directory = Path(source_directory)
        self.copy_directory = Path(copy_directory)
        self.target_size = target_size
        self.class_indices = self._get_class_indices()
        # Calculate min_count after obtaining all class indices to ensure it is available when needed
        self.min_count = min(len(files) for files in self.class_indices.values())
        self._log_class_info()

    def _get_class_indices(self):
        """Scan the source directory and map each class to its images."""
        class_indices = {}
        for class_name in os.listdir(self.source_directory):
            class_path = self.source_directory / class_name
            if class_path.is_dir():
                class_indices[class_name] = [str(class_path / fname) for fname in os.listdir(class_path)]
        return class_indices

    def _log_class_info(self):
        """Log information about the classes and their image counts."""
        logging.info(f"Number of unique classes: {len(self.class_indices)}")
        for class_name, files in self.class_indices.items():
            logging.info(f"Count of images in {class_name}: {len(files)}")
        logging.info(f"Minimum frequency among classes: {self.min_count}")
    
    def _augment_and_copy_image(self, source_path, target_path):
        """Resize image and save to target path."""
        try:
            with Image.open(source_path) as img:
                img_resized = img.resize(self.target_size, Image.Resampling.LANCZOS)
                img_resized.save(target_path)
            logging.debug(f"Image {source_path} resized and copied to {target_path}")
        except Exception as e:
            logging.error(f"Error processing image {source_path}: {e}")

    def copy_and_augment_balanced_dataset(self):
        """Copy and augment a balanced dataset to the copy directory."""
        logging.info("Starting to copy and augment the dataset...")
        for class_name, files in self.class_indices.items():
            copy_path = self.copy_directory / class_name
            copy_path.mkdir(parents=True, exist_ok=True)
            # Ensure we only process up to min_count images per class
            selected_files = files[:self.min_count]
            for file_path in selected_files:
                target_file_path = copy_path / Path(file_path).name
                self._augment_and_copy_image(file_path, target_file_path)
        logging.info(f"Augmented balanced dataset copied to {self.copy_directory}")

# %%
source_directory = Path(os.getcwd()) / "Dataset/images" / "train"
copy_directory = Path(os.getcwd()) / "Dataset/images" / "Balanced_train"
augmented_dataset_copier = CopyAndAugmentBalancedDataset(source_directory, copy_directory, target_size=(256, 256))
augmented_dataset_copier.copy_and_augment_balanced_dataset()
# Out:
# 2024-04-12 00:55:13 - INFO - Number of unique classes: 7
# 2024-04-12 00:55:13 - INFO - Count of images in angry: 3993
# 2024-04-12 00:55:13 - INFO - Count of images in disgust: 436
# 2024-04-12 00:55:13 - INFO - Count of images in fear: 4103
# 2024-04-12 00:55:13 - INFO - Count of images in happy: 7164
# 2024-04-12 00:55:13 - INFO - Count of images in neutral: 4982
# 2024-04-12 00:55:13 - INFO - Count of images in sad: 4938
# 2024-04-12 00:55:13 - INFO - Count of images in surprise: 3205
# 2024-04-12 00:55:13 - INFO - Minimum frequency among classes: 436
# 2024-04-12 00:55:13 - INFO - Starting to copy and augment the dataset...
# 2024-04-12 00:55:18 - INFO - Augmented balanced dataset copied to D:\Desktop\Deep Learning\GAN for Face expression Classification\Dataset\images\Balanced_train

# %%
import torch

if torch.cuda.is_available():
    print("CUDA is available! You can use GPU for accelerated computations.")
else:
    print("CUDA is not available. You can use CPU for computations.")
# Out:
# CUDA is not available. You can use CPU for computations.

# %%
#Parameters

# Root directory for dataset
dataroot = Path(os.getcwd()) / "Dataset/images" / "Balanced_train"

# Number of workers for dataloader
workers = 3

# Batch size during training
batch_size = 128

# Spatial size of training images. All images will be resized to this size using a transformer.
image_size = 256

# Number of channels in the training images. For color images this is 3
num_channels = 3

# Size of z latent vector (i.e. size of generator input)
nz = 100

# Size of feature maps in generator
ngf = 64

# Size of feature maps in discriminator
ndf = 64

# Number of training epochs
num_epochs = 10

# Learning rate for optimizers
lr = 0.0002

# Beta1 hyperparameter for Adam optimizers
beta1 = 0.5

# Number of GPUs available. Use 0 for CPU mode.
ngpu = 1

# Number of classes (for example)
num_classes = 7

# %%
import torchvision.transforms as transforms
import torchvision.datasets as dset
import matplotlib.pyplot as plt
import numpy as np
import torchvision.utils as vutils

# %%
#Preparing the dataset and applying transformations to the images in the dataset
transform = transforms.Compose([
    transforms.Resize(image_size),
    transforms.CenterCrop(image_size),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])
dataset = dset.ImageFolder(root=dataroot, transform=transform)

# %%
#Actually loading the data
dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                         shuffle=True, num_workers=workers)

# %%
# Deciding which device we want to run on
device = torch.device("cuda:0" if (torch.cuda.is_available() and ngpu > 0) else "cpu")
device
# Out:
# device(type='cpu')

# %%
# Plot some training images
real_batch = next(iter(dataloader))
plt.figure(figsize=(16,16))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device)[:64], padding=2, normalize=True).cpu(),(1,2,0)))
plt.show()

# %% [markdown]
# # Imports

# %%
import keras

from keras import layers
from keras import ops
from tensorflow_docs.vis import embed
import tensorflow as tf
import numpy as np
import imageio

# %% [markdown]
# # Constants and hyperparameters

# %%
batch_size = batch_size
num_channels = num_channels
num_classes = num_classes
image_size = image_size
latent_dim = 128

# %% [markdown]
# # Loading the Custom dataset and preprocessing it

# %%
import numpy as np
import tensorflow as tf

# Assuming you already have your PyTorch dataset defined as 'dataset'

# Separate images and labels
X = []
y = []
for img, label in dataset:
    X.append(img.numpy())  # Convert PyTorch tensor to NumPy array
    y.append(label)  # Append label directly without converting to NumPy array

# Concatenate the lists of arrays to create 'all_digits' and 'all_labels'
all_digits = np.concatenate(X, axis=0)
all_labels = np.array(y)  # Convert list to NumPy array

# Scale the pixel values to [0, 1] range, add a channel dimension to the images,
# and one-hot encode the labels.
all_digits = all_digits.astype("float32") / 255.0
all_digits = np.reshape(all_digits, (-1, image_size, image_size, num_channels))
all_labels = tf.keras.utils.to_categorical(all_labels, num_classes)

# Create TensorFlow Dataset from 'all_digits' and 'all_labels'
tf_dataset = tf.data.Dataset.from_tensor_slices((all_digits, all_labels))
dataset = tf_dataset.shuffle(buffer_size=len(all_digits)).batch(batch_size)

logging.info(f"Shape of training images: {all_digits.shape}")
logging.info(f"Shape of training labels: {all_labels.shape}")

# Print dataset size
logging.info(f"Number of samples: {len(all_digits)}")

# Print shapes of TensorFlow dataset
for img, label in dataset.take(1):  # Take a single batch for printing shapes
    logging.info(f"Shape of images: {img.shape}")
    logging.info(f"Shape of labels: {label.shape}")
# Out:
# 2024-04-11 21:13:17 - INFO - Shape of training images: (3052, 28, 28, 3)
# 2024-04-11 21:13:17 - INFO - Shape of training labels: (3052, 7)
# 2024-04-11 21:13:17 - INFO - Number of samples: 3052
# 2024-04-11 21:13:17 - INFO - Shape of images: (128, 28, 28, 3)
# 2024-04-11 21:13:17 - INFO - Shape of labels: (128, 7)

# %% [markdown]
# https://keras.io/examples/generative/conditional_gan/

# %% [markdown]
# # Calculating the number of input channel for the generator and discriminator
# In a regular (unconditional) GAN, we start by sampling noise (of some fixed dimension) from a normal distribution. In our case, we also need to account for the class labels. We will have to add the number of classes to the input channels of the generator (noise input) as well as the discriminator (generated image input).

# %%
generator_in_channels = latent_dim + num_classes
discriminator_in_channels = num_channels + num_classes
logging.info(f"generator_in_channels are {generator_in_channels} , discriminator_in_channels are {discriminator_in_channels}")
# Out:
# 2024-04-11 21:14:12 - INFO - generator_in_channels are 135 , discriminator_in_channels are 10

# %% [markdown]
# # Creating the discriminator and generator

# %%
import tensorflow.keras as keras
from tensorflow.keras import layers

# New image dimension
image_size = image_size


# Create the discriminator.
discriminator = keras.Sequential(
    [
        keras.layers.InputLayer((image_size, image_size, discriminator_in_channels)),
        layers.Conv2D(64, (3, 3), strides=(2, 2), padding="same"),
        layers.LeakyReLU(negative_slope=0.2),
        layers.Conv2D(128, (3, 3), strides=(2, 2), padding="same"),
        layers.LeakyReLU(negative_slope=0.2),
        layers.GlobalMaxPooling2D(),
        layers.Dense(1),
    ],
    name="discriminator",
)

# Create the generator.
generator = keras.Sequential(
    [
        keras.layers.InputLayer((generator_in_channels,)),
        layers.Dense(7 * 7 * generator_in_channels),
        layers.LeakyReLU(alpha=0.2),
        layers.Reshape((7, 7, generator_in_channels)),
        layers.Conv2DTranspose(128, (4, 4), strides=(2, 2), padding="same"),
        layers.LeakyReLU(alpha=0.2),
        layers.Conv2DTranspose(64, (4, 4), strides=(2, 2), padding="same"),
        layers.LeakyReLU(alpha=0.2),
        layers.Conv2D(3, (7, 7), padding="same", activation="tanh"),  # Output 3 channels for RGB
    ],
    name="generator",
)

# %%
discriminator.summary()
# Out:
# Model: "discriminator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape           ┃      Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━┩
# │ conv2d_37 (Conv2D)            │ (None, 14, 14, 64)     │        5,824 │
# ├───────────────────────────────┼────────────────────────┼──────────────┤
# │ leaky_re_lu_59 (LeakyReLU)    │ (None, 14, 14, 64)     │            0 │
# ├───────────────────────────────┼────────────────────────┼──────────────┤
# │ conv2d_38 (Conv2D)            │ (None, 7, 7, 128)      │       73,856 │
# ├───────────────────────────────┼────────────────────────┼──────────────┤
# │ leaky_re_lu_60 (LeakyReLU)    │ (None, 7, 7, 128)      │            0 │
# ├───────────────────────────────┼────────────────────────┼──────────────┤
# │ global_max_pooling2d_13       │ (None, 128)            │            0 │
# │ (GlobalMaxPooling2D)          │                        │              │
# ├───────────────────────────────┼────────────────────────┼──────────────┤
# │ dense_24 (Dense)              │ (None, 1)              │          129 │
# └───────────────────────────────┴────────────────────────┴──────────────┘
#  Total params: 79,809 (311.75 KB)
#  Trainable params: 79,809 (311.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
generator.summary()
# Out:
# Model: "generator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape           ┃      Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━┩
# │ dense_25 (Dense)              │ (None, 6615)           │      899,640 │
# ├───────────────────────────────┼────────────────────────┼──────────────┤
# │ leaky_re_lu_61 (LeakyReLU)    │ (None, 6615)           │            0 │
# ├───────────────────────────────┼────────────────────────┼──────────────┤
# │ reshape_11 (Reshape)          │ (None, 7, 7, 135)      │            0 │
# ├───────────────────────────────┼────────────────────────┼──────────────┤
# │ conv2d_transpose_22           │ (None, 14, 14, 128)    │      276,608 │
# │ (Conv2DTranspose)             │                        │              │
# ├───────────────────────────────┼────────────────────────┼──────────────┤
# │ leaky_re_lu_62 (LeakyReLU)    │ (None, 14, 14, 128)    │            0 │
# ├───────────────────────────────┼────────────────────────┼──────────────┤
# │ conv2d_transpose_23           │ (None, 28, 28, 64)     │      131,136 │
# │ (Conv2DTranspose)             │                        │              │
# ├───────────────────────────────┼────────────────────────┼──────────────┤
# │ leaky_re_lu_63 (LeakyReLU)    │ (None, 28, 28, 64)     │            0 │
# ├───────────────────────────────┼────────────────────────┼──────────────┤
# │ conv2d_39 (Conv2D)            │ (None, 28, 28, 3)      │        9,411 │
# └───────────────────────────────┴────────────────────────┴──────────────┘
#  Total params: 1,316,795 (5.02 MB)
#  Trainable params: 1,316,795 (5.02 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Creating a ConditionalGAN model

# %%
class ConditionalGAN(keras.Model):
    def __init__(self, discriminator, generator, latent_dim):
        super().__init__()
        self.discriminator = discriminator
        self.generator = generator
        self.latent_dim = latent_dim
        self.seed_generator = keras.random.SeedGenerator(1337)
        self.gen_loss_tracker = keras.metrics.Mean(name="generator_loss")
        self.disc_loss_tracker = keras.metrics.Mean(name="discriminator_loss")

    @property
    def metrics(self):
        return [self.gen_loss_tracker, self.disc_loss_tracker]

    def compile(self, d_optimizer, g_optimizer, loss_fn):
        super().compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.loss_fn = loss_fn

    def train_step(self, data):
        # Unpack the data.
        real_images, one_hot_labels = data

        logging.info(f"Real Images shape: {real_images.shape}")
        logging.info(f"One-hot Labels shape: {one_hot_labels.shape}")

        # Add dummy dimensions to the labels so that they can be concatenated with
        # the images. This is for the discriminator.
        logging.info(f"image shape: {image_size}")
        image_one_hot_labels = one_hot_labels[:, :, None, None]
        image_one_hot_labels = ops.repeat(
            image_one_hot_labels, repeats=[image_size * image_size]
        )
        logging.info(f"num_classes: {num_classes}")
        image_one_hot_labels = ops.reshape(
        image_one_hot_labels, (-1, image_size, image_size, num_classes)
        )

        # Sample random points in the latent space and concatenate the labels.
        # This is for the generator.
        batch_size = ops.shape(real_images)[0]
        random_latent_vectors = keras.random.normal(
            shape=(batch_size, self.latent_dim), seed=self.seed_generator
        )
        random_vector_labels = ops.concatenate(
            [random_latent_vectors, one_hot_labels], axis=1
        )

        # Decode the noise (guided by labels) to fake images.
        generated_images = self.generator(random_vector_labels)

        logging.info(f"Generated Images shape: {generated_images.shape}")

        # Combine them with real images. Note that we are concatenating the labels
        # with these images here.
        fake_image_and_labels = ops.concatenate(
            [generated_images, image_one_hot_labels], -1
        )
        real_image_and_labels = ops.concatenate([real_images, image_one_hot_labels], -1)
        combined_images = ops.concatenate(
            [fake_image_and_labels, real_image_and_labels], axis=0
        )

        # Assemble labels discriminating real from fake images.
        labels = ops.concatenate(
            [ops.ones((batch_size, 1)), ops.zeros((batch_size, 1))], axis=0
        )

        # Train the discriminator.
        with tf.GradientTape() as tape:
            predictions = self.discriminator(combined_images)
            d_loss = self.loss_fn(labels, predictions)
        grads = tape.gradient(d_loss, self.discriminator.trainable_weights)
        self.d_optimizer.apply_gradients(
            zip(grads, self.discriminator.trainable_weights)
        )

        # Sample random points in the latent space.
        random_latent_vectors = keras.random.normal(
            shape=(batch_size, self.latent_dim), seed=self.seed_generator
        )
        random_vector_labels = ops.concatenate(
            [random_latent_vectors, one_hot_labels], axis=1
        )

        # Assemble labels that say "all real images".
        misleading_labels = ops.zeros((batch_size, 1))

        # Train the generator (note that we should *not* update the weights
        # of the discriminator)!
        with tf.GradientTape() as tape:
            fake_images = self.generator(random_vector_labels)
            fake_image_and_labels = ops.concatenate(
                [fake_images, image_one_hot_labels], -1
            )
            predictions = self.discriminator(fake_image_and_labels)
            g_loss = self.loss_fn(misleading_labels, predictions)
        grads = tape.gradient(g_loss, self.generator.trainable_weights)
        self.g_optimizer.apply_gradients(zip(grads, self.generator.trainable_weights))

        # Monitor loss.
        self.gen_loss_tracker.update_state(g_loss)
        self.disc_loss_tracker.update_state(d_loss)

        logging.info(f"Generator Loss: {self.gen_loss_tracker.result()}")
        logging.info(f"Discriminator Loss: {self.disc_loss_tracker.result()}")
        
        return {
            "g_loss": self.gen_loss_tracker.result(),
            "d_loss": self.disc_loss_tracker.result(),
        }

# %% [markdown]
# # Training the Conditional GAN

# %%
cond_gan = ConditionalGAN(
    discriminator=discriminator, generator=generator, latent_dim=latent_dim
)
cond_gan.compile(
    d_optimizer=keras.optimizers.Adam(learning_rate=0.0003),
    g_optimizer=keras.optimizers.Adam(learning_rate=0.0003),
    loss_fn=keras.losses.BinaryCrossentropy(from_logits=True),
)

# Fit the model and capture the loss history
history = cond_gan.fit(dataset, epochs=100)
# Out:
# Epoch 1/100
# 2024-04-11 22:45:11 - INFO - Real Images shape: (None, 28, 28, 3)
# 2024-04-11 22:45:11 - INFO - One-hot Labels shape: (None, 7)
# 2024-04-11 22:45:11 - INFO - image shape: 28
# 2024-04-11 22:45:11 - INFO - num_classes: 7
# 2024-04-11 22:45:11 - INFO - Generated Images shape: (None, 28, 28, 3)
# 2024-04-11 22:45:12 - INFO - Generator Loss: Tensor("div_no_nan:0", shape=(), dtype=float32)
# 2024-04-11 22:45:12 - INFO - Discriminator Loss: Tensor("div_no_nan_1:0", shape=(), dtype=float32)
# 2024-04-11 22:45:12 - INFO - Real Images shape: (None, 28, 28, 3)
# 2024-04-11 22:45:12 - INFO - One-hot Labels shape: (None, 7)
# 2024-04-11 22:45:12 - INFO - image shape: 28
# 2024-04-11 22:45:12 - INFO - num_classes: 7
# 2024-04-11 22:45:12 - INFO - Generated Images shape: (None, 28, 28, 3)
# 2024-04-11 22:45:13 - INFO - Generator Loss: Tensor("div_no_nan:0", shape=(), dtype=float32)
# 2024-04-11 22:45:13 - INFO - Discriminator Loss: Tensor("div_no_nan_1:0", shape=(), dtype=float32)
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 255ms/step - d_loss: 0.6885 - g_loss: 0.7024 - discriminator_loss: 0.6884 - generator_loss: 0.7089
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 258ms/step - d_loss: 0.6933 - g_loss: 0.7076 - discriminator_loss: 0.6940 - generator_loss: 0.6978
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 260ms/step - d_loss: 0.6909 - g_loss: 0.6933 - discriminator_loss: 0.6902 - generator_loss: 0.6972
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 262ms/step - d_loss: 0.6921 - g_loss: 0.6978 - discriminator_loss: 0.6937 - generator_loss: 0.6956
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 263ms/step - d_loss: 0.6896 - g_loss: 0.7024 - discriminator_loss: 0.6870 - generator_loss: 0.7048
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 262ms/step - d_loss: 0.6958 - g_loss: 0.6944 - discriminator_loss: 0.6943 - generator_loss: 0.6964
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 262ms/step - d_loss: 0.6918 - g_loss: 0.7013 - discriminator_loss: 0.6884 - generator_loss: 0.7076
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 261ms/step - d_loss: 0.6888 - g_loss: 0.6941 - discriminator_loss: 0.6941 - generator_loss: 0.6935
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 254ms/step - d_loss: 0.6988 - g_loss: 0.6919 - discriminator_loss: 0.6970 - generator_loss: 0.6936
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 259ms/step - d_loss: 0.6870 - g_loss: 0.7029 - discriminator_loss: 0.6878 - generator_loss: 0.7019
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 256ms/step - d_loss: 0.6991 - g_loss: 0.6905 - discriminator_loss: 0.6956 - generator_loss: 0.6946
# Epoch 12/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 255ms/step - d_loss: 0.6932 - g_loss: 0.6956 - discriminator_loss: 0.6954 - generator_loss: 0.6930
# Epoch 13/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 258ms/step - d_loss: 0.6927 - g_loss: 0.6957 - discriminator_loss: 0.6911 - generator_loss: 0.6980
# Epoch 14/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 262ms/step - d_loss: 0.6949 - g_loss: 0.6946 - discriminator_loss: 0.6977 - generator_loss: 0.6913
# Epoch 15/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 259ms/step - d_loss: 0.6955 - g_loss: 0.6936 - discriminator_loss: 0.6933 - generator_loss: 0.6960
# Epoch 16/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 263ms/step - d_loss: 0.6951 - g_loss: 0.6948 - discriminator_loss: 0.6905 - generator_loss: 0.6996
# Epoch 17/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 254ms/step - d_loss: 0.6980 - g_loss: 0.6892 - discriminator_loss: 0.7016 - generator_loss: 0.6869
# Epoch 18/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 257ms/step - d_loss: 0.6937 - g_loss: 0.6968 - discriminator_loss: 0.6955 - generator_loss: 0.6945
# Epoch 19/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 255ms/step - d_loss: 0.6974 - g_loss: 0.6918 - discriminator_loss: 0.6946 - generator_loss: 0.6940
# Epoch 20/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 254ms/step - d_loss: 0.6978 - g_loss: 0.6896 - discriminator_loss: 0.6984 - generator_loss: 0.6894
# Epoch 21/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 261ms/step - d_loss: 0.6889 - g_loss: 0.7003 - discriminator_loss: 0.6928 - generator_loss: 0.6960
# Epoch 22/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 255ms/step - d_loss: 0.7021 - g_loss: 0.6868 - discriminator_loss: 0.6985 - generator_loss: 0.6914
# Epoch 23/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 253ms/step - d_loss: 0.6954 - g_loss: 0.6933 - discriminator_loss: 0.6947 - generator_loss: 0.6940
# Epoch 24/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 254ms/step - d_loss: 0.6963 - g_loss: 0.6919 - discriminator_loss: 0.6955 - generator_loss: 0.6927
# Epoch 25/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 255ms/step - d_loss: 0.6972 - g_loss: 0.6902 - discriminator_loss: 0.6978 - generator_loss: 0.6896
# Epoch 26/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 256ms/step - d_loss: 0.6927 - g_loss: 0.6953 - discriminator_loss: 0.6924 - generator_loss: 0.6961
# Epoch 27/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 257ms/step - d_loss: 0.6976 - g_loss: 0.6912 - discriminator_loss: 0.6969 - generator_loss: 0.6923
# Epoch 28/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 258ms/step - d_loss: 0.6954 - g_loss: 0.6937 - discriminator_loss: 0.6984 - generator_loss: 0.6909
# Epoch 29/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 254ms/step - d_loss: 0.6963 - g_loss: 0.6931 - discriminator_loss: 0.6974 - generator_loss: 0.6911
# Epoch 30/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 256ms/step - d_loss: 0.6988 - g_loss: 0.6892 - discriminator_loss: 0.6959 - generator_loss: 0.6923
# Epoch 31/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 259ms/step - d_loss: 0.6969 - g_loss: 0.6909 - discriminator_loss: 0.6960 - generator_loss: 0.6917
# Epoch 32/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 261ms/step - d_loss: 0.6932 - g_loss: 0.6945 - discriminator_loss: 0.6938 - generator_loss: 0.6937
# Epoch 33/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 257ms/step - d_loss: 0.6960 - g_loss: 0.6913 - discriminator_loss: 0.6945 - generator_loss: 0.6931
# Epoch 34/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 257ms/step - d_loss: 0.6952 - g_loss: 0.6923 - discriminator_loss: 0.6971 - generator_loss: 0.6905
# Epoch 35/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 261ms/step - d_loss: 0.6961 - g_loss: 0.6929 - discriminator_loss: 0.6947 - generator_loss: 0.6942
# Epoch 36/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 260ms/step - d_loss: 0.6998 - g_loss: 0.6885 - discriminator_loss: 0.6971 - generator_loss: 0.6917
# Epoch 37/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 260ms/step - d_loss: 0.6959 - g_loss: 0.6924 - discriminator_loss: 0.6978 - generator_loss: 0.6903
# Epoch 38/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 256ms/step - d_loss: 0.6949 - g_loss: 0.6925 - discriminator_loss: 0.6947 - generator_loss: 0.6924
# Epoch 39/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 260ms/step - d_loss: 0.6939 - g_loss: 0.6933 - discriminator_loss: 0.6942 - generator_loss: 0.6930
# Epoch 40/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 252ms/step - d_loss: 0.6957 - g_loss: 0.6914 - discriminator_loss: 0.6948 - generator_loss: 0.6926
# Epoch 41/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 263ms/step - d_loss: 0.6918 - g_loss: 0.6954 - discriminator_loss: 0.6934 - generator_loss: 0.6937
# Epoch 42/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 264ms/step - d_loss: 0.6961 - g_loss: 0.6909 - discriminator_loss: 0.6949 - generator_loss: 0.6923
# Epoch 43/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 259ms/step - d_loss: 0.6940 - g_loss: 0.6929 - discriminator_loss: 0.6952 - generator_loss: 0.6917
# Epoch 44/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 260ms/step - d_loss: 0.6956 - g_loss: 0.6915 - discriminator_loss: 0.6946 - generator_loss: 0.6928
# Epoch 45/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 260ms/step - d_loss: 0.6938 - g_loss: 0.6939 - discriminator_loss: 0.6952 - generator_loss: 0.6923
# Epoch 46/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 268ms/step - d_loss: 0.6946 - g_loss: 0.6930 - discriminator_loss: 0.6948 - generator_loss: 0.6925
# Epoch 47/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 261ms/step - d_loss: 0.6959 - g_loss: 0.6916 - discriminator_loss: 0.6950 - generator_loss: 0.6927
# Epoch 48/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 259ms/step - d_loss: 0.6959 - g_loss: 0.6912 - discriminator_loss: 0.6966 - generator_loss: 0.6906
# Epoch 49/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 260ms/step - d_loss: 0.6924 - g_loss: 0.6951 - discriminator_loss: 0.6931 - generator_loss: 0.6943
# Epoch 50/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 259ms/step - d_loss: 0.6946 - g_loss: 0.6927 - discriminator_loss: 0.6944 - generator_loss: 0.6930
# Epoch 51/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 258ms/step - d_loss: 0.6944 - g_loss: 0.6930 - discriminator_loss: 0.6949 - generator_loss: 0.6925
# Epoch 52/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 260ms/step - d_loss: 0.6955 - g_loss: 0.6917 - discriminator_loss: 0.6945 - generator_loss: 0.6926
# Epoch 53/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 261ms/step - d_loss: 0.6954 - g_loss: 0.6912 - discriminator_loss: 0.6959 - generator_loss: 0.6908
# Epoch 54/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 262ms/step - d_loss: 0.6941 - g_loss: 0.6932 - discriminator_loss: 0.6933 - generator_loss: 0.6940
# Epoch 55/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 260ms/step - d_loss: 0.6951 - g_loss: 0.6922 - discriminator_loss: 0.6955 - generator_loss: 0.6920
# Epoch 56/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 257ms/step - d_loss: 0.6952 - g_loss: 0.6926 - discriminator_loss: 0.6954 - generator_loss: 0.6922
# Epoch 57/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 259ms/step - d_loss: 0.6956 - g_loss: 0.6914 - discriminator_loss: 0.6952 - generator_loss: 0.6919
# Epoch 58/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 262ms/step - d_loss: 0.6936 - g_loss: 0.6932 - discriminator_loss: 0.6941 - generator_loss: 0.6927
# Epoch 59/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 262ms/step - d_loss: 0.6957 - g_loss: 0.6914 - discriminator_loss: 0.6948 - generator_loss: 0.6924
# Epoch 60/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 262ms/step - d_loss: 0.6957 - g_loss: 0.6916 - discriminator_loss: 0.6959 - generator_loss: 0.6917
# Epoch 61/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 261ms/step - d_loss: 0.6936 - g_loss: 0.6937 - discriminator_loss: 0.6947 - generator_loss: 0.6925
# Epoch 62/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 266ms/step - d_loss: 0.6947 - g_loss: 0.6928 - discriminator_loss: 0.6953 - generator_loss: 0.6918
# Epoch 63/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 187ms/step - d_loss: 0.6953 - g_loss: 0.6916 - discriminator_loss: 0.6940 - generator_loss: 0.6931
# Epoch 64/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - d_loss: 0.6947 - g_loss: 0.6921 - discriminator_loss: 0.6951 - generator_loss: 0.6919
# Epoch 65/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - d_loss: 0.6947 - g_loss: 0.6923 - discriminator_loss: 0.6941 - generator_loss: 0.6929
# Epoch 66/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - d_loss: 0.6948 - g_loss: 0.6922 - discriminator_loss: 0.6957 - generator_loss: 0.6913
# Epoch 67/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - d_loss: 0.6936 - g_loss: 0.6938 - discriminator_loss: 0.6941 - generator_loss: 0.6931
# Epoch 68/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - d_loss: 0.6950 - g_loss: 0.6919 - discriminator_loss: 0.6945 - generator_loss: 0.6924
# Epoch 69/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - d_loss: 0.6948 - g_loss: 0.6920 - discriminator_loss: 0.6943 - generator_loss: 0.6925
# Epoch 70/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - d_loss: 0.6953 - g_loss: 0.6915 - discriminator_loss: 0.6956 - generator_loss: 0.6915
# Epoch 71/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - d_loss: 0.6930 - g_loss: 0.6946 - discriminator_loss: 0.6941 - generator_loss: 0.6932
# Epoch 72/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - d_loss: 0.6941 - g_loss: 0.6938 - discriminator_loss: 0.6957 - generator_loss: 0.6918
# Epoch 73/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - d_loss: 0.6964 - g_loss: 0.6920 - discriminator_loss: 0.6952 - generator_loss: 0.6926
# Epoch 74/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - d_loss: 0.6950 - g_loss: 0.6923 - discriminator_loss: 0.6943 - generator_loss: 0.6929
# Epoch 75/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - d_loss: 0.6955 - g_loss: 0.6910 - discriminator_loss: 0.6955 - generator_loss: 0.6915
# Epoch 76/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - d_loss: 0.6938 - g_loss: 0.6927 - discriminator_loss: 0.6948 - generator_loss: 0.6923
# Epoch 77/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - d_loss: 0.6941 - g_loss: 0.6933 - discriminator_loss: 0.6943 - generator_loss: 0.6928
# Epoch 78/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - d_loss: 0.6941 - g_loss: 0.6938 - discriminator_loss: 0.6937 - generator_loss: 0.6938
# Epoch 79/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - d_loss: 0.6947 - g_loss: 0.6937 - discriminator_loss: 0.6951 - generator_loss: 0.6922
# Epoch 80/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - d_loss: 0.6943 - g_loss: 0.6912 - discriminator_loss: 0.6936 - generator_loss: 0.6929
# Epoch 81/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - d_loss: 0.6946 - g_loss: 0.6924 - discriminator_loss: 0.6951 - generator_loss: 0.6918
# Epoch 82/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - d_loss: 0.6942 - g_loss: 0.6923 - discriminator_loss: 0.6936 - generator_loss: 0.6930
# Epoch 83/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - d_loss: 0.6942 - g_loss: 0.6924 - discriminator_loss: 0.6945 - generator_loss: 0.6922
# Epoch 84/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - d_loss: 0.6943 - g_loss: 0.6925 - discriminator_loss: 0.6940 - generator_loss: 0.6928
# Epoch 85/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - d_loss: 0.6940 - g_loss: 0.6928 - discriminator_loss: 0.6947 - generator_loss: 0.6920
# Epoch 86/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - d_loss: 0.6940 - g_loss: 0.6931 - discriminator_loss: 0.6934 - generator_loss: 0.6938
# Epoch 87/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - d_loss: 0.6953 - g_loss: 0.6917 - discriminator_loss: 0.6957 - generator_loss: 0.6915
# Epoch 88/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - d_loss: 0.6927 - g_loss: 0.6946 - discriminator_loss: 0.6928 - generator_loss: 0.6941
# Epoch 89/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - d_loss: 0.6950 - g_loss: 0.6917 - discriminator_loss: 0.6949 - generator_loss: 0.6919
# Epoch 90/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - d_loss: 0.6939 - g_loss: 0.6930 - discriminator_loss: 0.6943 - generator_loss: 0.6925
# Epoch 91/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - d_loss: 0.6945 - g_loss: 0.6924 - discriminator_loss: 0.6942 - generator_loss: 0.6928
# Epoch 92/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - d_loss: 0.6944 - g_loss: 0.6926 - discriminator_loss: 0.6948 - generator_loss: 0.6922
# Epoch 93/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - d_loss: 0.6939 - g_loss: 0.6935 - discriminator_loss: 0.6942 - generator_loss: 0.6930
# Epoch 94/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - d_loss: 0.6966 - g_loss: 0.6905 - discriminator_loss: 0.6952 - generator_loss: 0.6921
# Epoch 95/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - d_loss: 0.6939 - g_loss: 0.6929 - discriminator_loss: 0.6949 - generator_loss: 0.6919
# Epoch 96/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - d_loss: 0.6952 - g_loss: 0.6920 - discriminator_loss: 0.6941 - generator_loss: 0.6933
# Epoch 97/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - d_loss: 0.6942 - g_loss: 0.6926 - discriminator_loss: 0.6954 - generator_loss: 0.6913
# Epoch 98/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - d_loss: 0.6959 - g_loss: 0.6924 - discriminator_loss: 0.6949 - generator_loss: 0.6939
# Epoch 99/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - d_loss: 0.6945 - g_loss: 0.6938 - discriminator_loss: 0.6950 - generator_loss: 0.6924
# Epoch 100/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - d_loss: 0.6954 - g_loss: 0.6922 - discriminator_loss: 0.6950 - generator_loss: 0.6922

# %%
# from pathlib import Path

# # Define the directory to save the models
# save_dir = Path(os.getcwd()) / "Model" / "CGAN"

# # Ensure the directory exists
# save_dir.mkdir(parents=True, exist_ok=True)

# # Save the generator and discriminator models
# cond_gan.generator.save(save_dir / "generator_model.keras")
# cond_gan.discriminator.save(save_dir / "discriminator_model.keras")

# %% [markdown]
# # Retraining CGAN

# %%
from pathlib import Path
import tensorflow as tf
from keras.models import load_model

# Define the directory where the models are saved
save_dir = Path(os.getcwd()) / "Model" / "CGAN"

# Load the generator and discriminator models
generator_model_path = save_dir / "generator_model.keras"
discriminator_model_path = save_dir / "discriminator_model.keras"

generator = load_model(generator_model_path)
discriminator = load_model(discriminator_model_path)

# Compile the loaded generator and discriminator models
# Make sure to provide the appropriate optimizer and loss function configurations
generator.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.0003),
    loss=keras.losses.BinaryCrossentropy(from_logits=True)
)
discriminator.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.0003),
    loss=keras.losses.BinaryCrossentropy(from_logits=True)
)
# Out:
# D:\Desktop\Deep Learning\GAN for Face expression Classification\venv\Lib\site-packages\keras\src\saving\saving_lib.py:418: UserWarning: Skipping variable loading for optimizer 'adam', because it has 18 variables whereas the saved optimizer has 2 variables.
#   trackable.load_own_variables(weights_store.get(inner_path))
# D:\Desktop\Deep Learning\GAN for Face expression Classification\venv\Lib\site-packages\keras\src\saving\saving_lib.py:418: UserWarning: Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 2 variables.
#   trackable.load_own_variables(weights_store.get(inner_path))

# %%
generator.summary()
# Out:
# Model: "generator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape           ┃      Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━┩
# │ dense_25 (Dense)              │ (None, 6615)           │      899,640 │
# ├───────────────────────────────┼────────────────────────┼──────────────┤
# │ leaky_re_lu_61 (LeakyReLU)    │ (None, 6615)           │            0 │
# ├───────────────────────────────┼────────────────────────┼──────────────┤
# │ reshape_11 (Reshape)          │ (None, 7, 7, 135)      │            0 │
# ├───────────────────────────────┼────────────────────────┼──────────────┤
# │ conv2d_transpose_22           │ (None, 14, 14, 128)    │      276,608 │
# │ (Conv2DTranspose)             │                        │              │
# ├───────────────────────────────┼────────────────────────┼──────────────┤
# │ leaky_re_lu_62 (LeakyReLU)    │ (None, 14, 14, 128)    │            0 │
# ├───────────────────────────────┼────────────────────────┼──────────────┤
# │ conv2d_transpose_23           │ (None, 28, 28, 64)     │      131,136 │
# │ (Conv2DTranspose)             │                        │              │
# ├───────────────────────────────┼────────────────────────┼──────────────┤
# │ leaky_re_lu_63 (LeakyReLU)    │ (None, 28, 28, 64)     │            0 │
# ├───────────────────────────────┼────────────────────────┼──────────────┤
# │ conv2d_39 (Conv2D)            │ (None, 28, 28, 3)      │        9,411 │
# └───────────────────────────────┴────────────────────────┴──────────────┘
#  Total params: 1,316,795 (5.02 MB)
#  Trainable params: 1,316,795 (5.02 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
discriminator.summary()
# Out:
# Model: "discriminator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape           ┃      Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━┩
# │ conv2d_37 (Conv2D)            │ (None, 14, 14, 64)     │        5,824 │
# ├───────────────────────────────┼────────────────────────┼──────────────┤
# │ leaky_re_lu_59 (LeakyReLU)    │ (None, 14, 14, 64)     │            0 │
# ├───────────────────────────────┼────────────────────────┼──────────────┤
# │ conv2d_38 (Conv2D)            │ (None, 7, 7, 128)      │       73,856 │
# ├───────────────────────────────┼────────────────────────┼──────────────┤
# │ leaky_re_lu_60 (LeakyReLU)    │ (None, 7, 7, 128)      │            0 │
# ├───────────────────────────────┼────────────────────────┼──────────────┤
# │ global_max_pooling2d_13       │ (None, 128)            │            0 │
# │ (GlobalMaxPooling2D)          │                        │              │
# ├───────────────────────────────┼────────────────────────┼──────────────┤
# │ dense_24 (Dense)              │ (None, 1)              │          129 │
# └───────────────────────────────┴────────────────────────┴──────────────┘
#  Total params: 79,809 (311.75 KB)
#  Trainable params: 79,809 (311.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Reinitialize the conditional GAN with the loaded models
cond_gan = ConditionalGAN(
    discriminator=discriminator, generator=generator, latent_dim=latent_dim
)

# Compile the conditional GAN
cond_gan.compile(
    d_optimizer=keras.optimizers.Adam(learning_rate=0.0003),
    g_optimizer=keras.optimizers.Adam(learning_rate=0.0003),
    loss_fn=keras.losses.BinaryCrossentropy(from_logits=True),
)

# Retrain the conditional GAN and save the models again
history = cond_gan.fit(dataset, epochs=2)

# Save the generator and discriminator models again
cond_gan.generator.save(save_dir / "generator_model_retrained.keras")
cond_gan.discriminator.save(save_dir / "discriminator_model_retrained.keras")
# Out:
# Epoch 1/2
# 2024-04-11 22:57:44 - INFO - Real Images shape: (None, 28, 28, 3)
# 2024-04-11 22:57:44 - INFO - One-hot Labels shape: (None, 7)
# 2024-04-11 22:57:44 - INFO - image shape: 28
# 2024-04-11 22:57:44 - INFO - num_classes: 7
# 2024-04-11 22:57:44 - INFO - Generated Images shape: (None, 28, 28, 3)
# 2024-04-11 22:57:45 - INFO - Generator Loss: Tensor("div_no_nan:0", shape=(), dtype=float32)
# 2024-04-11 22:57:45 - INFO - Discriminator Loss: Tensor("div_no_nan_1:0", shape=(), dtype=float32)
# 2024-04-11 22:57:45 - INFO - Real Images shape: (None, 28, 28, 3)
# 2024-04-11 22:57:45 - INFO - One-hot Labels shape: (None, 7)
# 2024-04-11 22:57:45 - INFO - image shape: 28
# 2024-04-11 22:57:45 - INFO - num_classes: 7
# 2024-04-11 22:57:46 - INFO - Generated Images shape: (None, 28, 28, 3)
# 2024-04-11 22:57:46 - INFO - Generator Loss: Tensor("div_no_nan:0", shape=(), dtype=float32)
# 2024-04-11 22:57:46 - INFO - Discriminator Loss: Tensor("div_no_nan_1:0", shape=(), dtype=float32)
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 259ms/step - d_loss: 0.6971 - g_loss: 0.7106 - discriminator_loss: 0.6957 - generator_loss: 0.6984
# Epoch 2/2
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 258ms/step - d_loss: 0.6937 - g_loss: 0.6855 - discriminator_loss: 0.6937 - generator_loss: 0.6913

# %% [markdown]
# # Plots

# %%
import matplotlib.pyplot as plt
# Save plots
plots_path = Path(os.getcwd()) / "Model" / "CGAN"
plt.style.use('dark_background')

# Extract generator and discriminator loss from the history
G_losses = history.history['generator_loss']
D_losses = history.history['discriminator_loss']

# Plot the generator and discriminator loss
plt.figure(figsize=(10,5))
plt.title("Generator and Discriminator Loss During Training")
plt.plot(G_losses,label="G")
plt.plot(D_losses,label="D")
plt.xlabel("epochs")
plt.ylabel("Loss")
plt.legend()
plt.savefig(plots_path / "Balanced_CGAN_Generator and Discriminator Loss.png")
plt.show()

# %% [markdown]
# # Interpolating between classes with the trained generator

# %%
# We first extract the trained generator from our Conditional GAN.
trained_gen = cond_gan.generator

# Choose the number of intermediate images that would be generated in
# between the interpolation + 2 (start and last images).
num_interpolation = 100 # @param {type:"integer"}

# Sample noise for the interpolation.
interpolation_noise = keras.random.normal(shape=(1, latent_dim))
interpolation_noise = ops.repeat(interpolation_noise, repeats=num_interpolation)
interpolation_noise = ops.reshape(interpolation_noise, (num_interpolation, latent_dim))


def interpolate_class(first_number, second_number):
    # Convert the start and end labels to one-hot encoded vectors.
    first_label = keras.utils.to_categorical([first_number], num_classes)
    second_label = keras.utils.to_categorical([second_number], num_classes)
    first_label = ops.cast(first_label, "float32")
    second_label = ops.cast(second_label, "float32")

    # Calculate the interpolation vector between the two labels.
    percent_second_label = ops.linspace(0, 1, num_interpolation)[:, None]
    percent_second_label = ops.cast(percent_second_label, "float32")
    interpolation_labels = (
        first_label * (1 - percent_second_label) + second_label * percent_second_label
    )

    # Combine the noise and the labels and run inference with the generator.
    noise_and_labels = ops.concatenate([interpolation_noise, interpolation_labels], 1)
    fake = trained_gen.predict(noise_and_labels)
    return fake


start_class = 0  # @param {type:"slider", min:0, max:9, step:1}
end_class = 6  # @param {type:"slider", min:0, max:9, step:1}

fake_images = interpolate_class(start_class, end_class)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
fake_images *= 255.0
converted_images = fake_images.astype(np.uint8)
converted_images = ops.image.resize(converted_images, (96, 96)).numpy().astype(np.uint8)
imageio.mimsave("animation.gif", converted_images[:, :, :, 0], fps=1)
embed.embed_file("animation.gif")
# Out:
# <img src="data:image/gif;base64,..."/>

# %%
import matplotlib.pyplot as plt

# Assuming converted_images is a list of 64 images

fig, axs = plt.subplots(8, 8, figsize=(16, 16))

for i in range(8):
    for j in range(8):
        index = i * 8 + j
        axs[i, j].imshow(converted_images[index], cmap='gray')
        axs[i, j].axis('off')

plt.show()
